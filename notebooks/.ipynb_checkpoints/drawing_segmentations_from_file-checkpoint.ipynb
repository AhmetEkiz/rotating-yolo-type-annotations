# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import torch
import numpy as np

import glob
from tqdm import tqdm

# %% [markdown]
# # Instance Segmentation with YoloV8

# %%
# Load a model
model = YOLO('../models/yolov8n-seg.pt')  # pretrained YOLOv8n model

# %%
# Read an image
image = cv2.imread('../images/bus.jpg')

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
results = model.predict(image)
# Out:
# 0: 640x480 4 persons, 1 bus, 1 skateboard, 79.1ms
# Speed: 8.5ms preprocess, 79.1ms inference, 46.9ms postprocess per image at shape (1, 3, 640, 480)

# %%
res_plotted = results[0].plot(pil=True)
plt.imshow(cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # Review the Result Shapes

# %%
results[0].masks[0].xy[0].astype(int)
# Out:
# array([[804, 391],
#        [794, 401],
#        [794, 403],
#        [791, 406],
#        [791, 408],
#        [789, 410],
#        [789, 423],
#        [788, 425],
#        [788, 430],
#        [789, 432],
#        [789, 445],
#        [791, 447],
#        [791, 450],
#        [793, 452],
#        [793, 453],
#        [794, 455],
#        [794, 465],
#        [793, 467],
#        [793, 469],
#        [789, 472],
#        [789, 475],
#        [788, 477],
#        [788, 479],
#        [786, 480],
#        [786, 482],
#        [784, 484],
#        [784, 486],
#        [783, 487],
#        [783, 489],
#        [777, 494],
#        [777, 496],
#        [776, 497],
#        [776, 501],
#        [774, 502],
#        [774, 506],
#        [772, 507],
#        [772, 509],
#        [771, 511],
#        [771, 516],
#        [769, 518],
#        [769, 519],
#        [767, 521],
#        [767, 528],
#        [766, 529],
#        [766, 533],
#        [761, 538],
#        [757, 538],
#        [756, 536],
#        [754, 536],
#        [752, 534],
#        [744, 534],
#        [742, 536],
#        [740, 536],
#        [739, 538],
#        [737, 538],
#        [735, 540],
#        [732, 540],
#        [730, 541],
#        [729, 541],
#        [727, 543],
#        [725, 543],
#        [723, 545],
#        [723, 546],
#        [720, 550],
#        [720, 551],
#        [718, 553],
#        [718, 556],
#        [722, 560],
#        [722, 561],
#        [723, 563],
#        [725, 563],
#        [727, 565],
#        [727, 567],
#        [737, 577],
#        [739, 577],
#        [745, 583],
#        [747, 583],
#        [759, 595],
#        [759, 597],
#        [761, 599],
#        [761, 607],
#        [759, 609],
#        [759, 617],
#        [757, 619],
#        [757, 626],
#        [756, 627],
#        [756, 637],
#        [754, 639],
#        [754, 648],
#        [752, 649],
#        [752, 653],
#        [750, 654],
#        [750, 659],
#        [749, 661],
#        [749, 668],
#        [747, 669],
#        [747, 678],
#        [749, 680],
#        [749, 683],
#        [750, 685],
#        [750, 686],
#        [754, 690],
#        [754, 698],
#        [752, 700],
#        [752, 702],
#        [750, 703],
#        [750, 705],
#        [749, 707],
#        [749, 710],
#        [747, 712],
#        [747, 717],
#        [745, 718],
#        [745, 720],
#        [744, 722],
#        [744, 723],
#        [742, 725],
#        [742, 730],
#        [740, 732],
#        [740, 740],
#        [739, 742],
#        [739, 747],
#        [737, 749],
#        [737, 752],
#        [735, 754],
#        [735, 761],
#        [734, 762],
#        [734, 767],
#        [732, 769],
#        [732, 771],
#        [730, 772],
#        [730, 774],
#        [729, 776],
#        [729, 779],
#        [727, 781],
#        [727, 784],
#        [725, 786],
#        [725, 788],
#        [722, 791],
#        [722, 794],
#        [720, 796],
#        [720, 801],
#        [718, 803],
#        [718, 804],
#        [715, 808],
#        [715, 811],
#        [713, 813],
#        [713, 815],
#        [705, 823],
#        [703, 823],
#        [702, 825],
#        [698, 825],
#        [696, 826],
#        [690, 826],
#        [688, 825],
#        [676, 825],
#        [676, 830],
#        [675, 831],
#        [675, 837],
#        [676, 838],
#        [676, 842],
#        [681, 847],
#        [681, 848],
#        [683, 848],
#        [686, 852],
#        [688, 852],
#        [691, 855],
#        [695, 855],
#        [696, 857],
#        [700, 857],
#        [702, 858],
#        [703, 858],
#        [707, 862],
#        [708, 862],
#        [710, 864],
#        [713, 864],
#        [715, 865],
#        [717, 865],
#        [718, 867],
#        [720, 867],
#        [723, 870],
#        [732, 870],
#        [734, 869],
#        [735, 869],
#        [735, 867],
#        [739, 864],
#        [739, 862],
#        [740, 860],
#        [740, 853],
#        [742, 852],
#        [742, 847],
#        [744, 845],
#        [744, 843],
#        [745, 842],
#        [745, 838],
#        [747, 837],
#        [747, 831],
#        [749, 830],
#        [749, 826],
#        [752, 823],
#        [752, 821],
#        [754, 820],
#        [754, 818],
#        [756, 816],
#        [756, 815],
#        [757, 813],
#        [757, 811],
#        [761, 808],
#        [761, 803],
#        [762, 801],
#        [762, 798],
#        [764, 796],
#        [764, 794],
#        [767, 791],
#        [767, 788],
#        [769, 786],
#        [769, 784],
#        [772, 781],
#        [772, 779],
#        [774, 777],
#        [774, 771],
#        [776, 769],
#        [776, 764],
#        [779, 761],
#        [779, 759],
#        [781, 757],
#        [781, 754],
#        [783, 752],
#        [783, 750],
#        [786, 747],
#        [786, 745],
#        [788, 744],
#        [788, 740],
#        [789, 739],
#        [789, 737],
#        [794, 732],
#        [794, 730],
#        [796, 729],
#        [796, 727],
#        [799, 723],
#        [799, 722],
#        [801, 720],
#        [801, 718],
#        [806, 713],
#        [808, 713],
#        [808, 391]])

# %%
results[0].masks[0].xy[0].shape
# Out:
# (245, 2)

# %% [markdown]
# # Draw Segmentations One-by-one with OpenCV

# %%
img_temp = image.copy()

k=0

for mask in results[0].masks:
    p1 = [-1, -1]
    p2 = [-1, -1]

    for i, xy in enumerate(mask.xy):
        points = xy.astype(int)
        img_temp = cv2.drawContours(img_temp, [points], 0, (0, 0, 255), 5)
    # print(i)
    
    k+=1
    if k==2:
        break

# %%
plt.imshow(cv2.cvtColor(img_temp, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Read the Annotation Files

# %%
# !chdir
# Out:
# H:\My Drive\Projects\yolo-segmentation-tool\notebooks

# %%
dataset_PATH = "../data/example_dataset_1_YOLO/"

# %%
folders = glob.glob(dataset_PATH+"/*/")
folders
# Out:
# ['../data/example_dataset_1_YOLO\\train\\',
#  '../data/example_dataset_1_YOLO\\test\\',
#  '../data/example_dataset_1_YOLO\\val\\']

# %%
print(glob.glob(dataset_PATH+"/*"))
print(glob.glob(dataset_PATH+"/*/"))   # find just folders
print(folders)
print(folders[0].split("\\"))
print(folders[0].split("\\")[-2])
# Out:
# ['../data/example_dataset_1_YOLO\\train', '../data/example_dataset_1_YOLO\\data.yaml', '../data/example_dataset_1_YOLO\\test', '../data/example_dataset_1_YOLO\\val']
# ['../data/example_dataset_1_YOLO\\train\\', '../data/example_dataset_1_YOLO\\test\\', '../data/example_dataset_1_YOLO\\val\\']
# ['../data/example_dataset_1_YOLO\\train\\', '../data/example_dataset_1_YOLO\\test\\', '../data/example_dataset_1_YOLO\\val\\']
# ['../data/example_dataset_1_YOLO', 'train', '']
# train

# %%
glob.glob(dataset_PATH+"/train/*")
# Out:
# ['../data/example_dataset_1_YOLO//train\\images',
#  '../data/example_dataset_1_YOLO//train\\labels']

# %%
glob.glob(dataset_PATH+"/train/images/*")
# Out:
# ['../data/example_dataset_1_YOLO//train/images\\vertical_1.jpg',
#  '../data/example_dataset_1_YOLO//train/images\\vertical_2.jpg']

# %%
folders = []

# %%
# find all images and annotations in the train, test, and val folders if they exists
for folder in glob.glob(dataset_PATH+"/*/"):
    folder_name = folder.split("\\")[-2]    # it suppose to be train, test, val
    print(f"Processing in {folder_name}...")
    
    sub_folder_PATH = f"{dataset_PATH}/{folder_name}/"    #  PATH of train, test, val
    
    # sub_folders_names = ["images", "labels"]
    
    for image_PATH in glob.glob(sub_folder_PATH+"/images/*"):
        image_name = image_PATH.split("\\")[-1]
        label_PATH = f"{sub_folder_PATH}/labels/{image_name.split('.')[0]}.txt"
        
        print("image_PATH: ", image_PATH)
        print("image_name: ", image_name)
        print("label_PATH: ", label_PATH)
        
        print()
        # read the annotation file
        # Parse the YOLO annotation file
        with open(label_PATH, "r") as file:
            lines = file.readlines()
        # print(lines)
        
        for line in lines:
            data = line.strip().split()
            print(data)
            
            class_id = int(data[0])
            points = list(map(float, data[1:]))
            
            # find x and y
            x = points[0::2]
            y = points[1::2]
            print("x: ", x[:4])
            print("y: ",y[:4])
            print(type(x))
            points_new = np.array(list(zip(x, y)))
            print("\nPOINTS NEW:\n", points_new)
        print()
# Out:
# Processing in train...
# image_PATH:  ../data/example_dataset_1_YOLO//train//images\vertical_1.jpg
# image_name:  vertical_1.jpg
# label_PATH:  ../data/example_dataset_1_YOLO//train//labels/vertical_1.txt
#
# ['0', '0.0342253', '0.514492', '0.0338477', '0.512007', '0.0347396', '0.509141', '0.38069', '0.110723', '0.384382', '0.108911', '0.386549', '0.106426', '0.386549', '0.105757', '0.389355', '0.105088', '0.391517', '0.105469', '0.392923', '0.10585', '0.395853', '0.108145', '0.400182', '0.108813', '0.401328', '0.109385', '0.403112', '0.110723', '0.404642', '0.111108', '0.413561', '0.114263', '0.417767', '0.1177', '0.751484', '0.281406', '0.75582', '0.285322', '0.75582', '0.287617', '0.754414', '0.2902', '0.752253', '0.291348', '0.750723', '0.293354', '0.749193', '0.295264', '0.416491', '0.688901', '0.414583', '0.68938', '0.411139', '0.689761', '0.40834', '0.691577', '0.405788', '0.691675', '0.403366', '0.690239', '0.40222', '0.68957', '0.398783', '0.689189', '0.398529', '0.689951', '0.397891', '0.690908', '0.396361', '0.691289', '0.066849', '0.536665', '0.0551237', '0.530547', '0.0497721', '0.527012', '0.0439128', '0.526152', '0.0441667', '0.524238', '0.042513', '0.522617', '0.0394531', '0.521758', '0.036901', '0.520513', '0.0357552', '0.517549']
# x:  [0.0342253, 0.0338477, 0.0347396, 0.38069]
# y:  [0.514492, 0.512007, 0.509141, 0.110723]
# <class 'list'>
#
# POINTS NEW:
#  [[   0.034225     0.51449]
#  [   0.033848     0.51201]
#  [    0.03474     0.50914]
#  [    0.38069     0.11072]
#  [    0.38438     0.10891]
#  [    0.38655     0.10643]
#  [    0.38655     0.10576]
#  [    0.38936     0.10509]
#  [    0.39152     0.10547]
#  [    0.39292     0.10585]
#  [    0.39585     0.10815]
#  [    0.40018     0.10881]
#  [    0.40133     0.10938]
#  [    0.40311     0.11072]
#  [    0.40464     0.11111]
#  [    0.41356     0.11426]
#  [    0.41777      0.1177]
#  [    0.75148     0.28141]
#  [    0.75582     0.28532]
#  [    0.75582     0.28762]
#  [    0.75441      0.2902]
#  [    0.75225     0.29135]
#  [    0.75072     0.29335]
#  [    0.74919     0.29526]
#  [    0.41649      0.6889]
#  [    0.41458     0.68938]
#  [    0.41114     0.68976]
#  [    0.40834     0.69158]
#  [    0.40579     0.69168]
#  [    0.40337     0.69024]
#  [    0.40222     0.68957]
#  [    0.39878     0.68919]
#  [    0.39853     0.68995]
#  [    0.39789     0.69091]
#  [    0.39636     0.69129]
#  [   0.066849     0.53666]
#  [   0.055124     0.53055]
#  [   0.049772     0.52701]
#  [   0.043913     0.52615]
#  [   0.044167     0.52424]
#  [   0.042513     0.52262]
#  [   0.039453     0.52176]
#  [   0.036901     0.52051]
#  [   0.035755     0.51755]]
# ['1', '0.662435', '0.596289', '0.658854', '0.591943', '0.659505', '0.588379', '0.660156', '0.577637', '0.667318', '0.535156', '0.666016', '0.534668', '0.667969', '0.532227', '0.677083', '0.475098', '0.676432', '0.472656', '0.679688', '0.458984', '0.691406', '0.384277', '0.690755', '0.382812', '0.681641', '0.380859', '0.684896', '0.378418', '0.6875', '0.371582', '0.686849', '0.369141', '0.690104', '0.365723', '0.692708', '0.361328', '0.707031', '0.361816', '0.708333', '0.35791', '0.711589', '0.35498', '0.714193', '0.355957', '0.742188', '0.356934', '0.74349', '0.355957', '0.75', '0.355469', '0.752604', '0.35498', '0.775391', '0.351074', '0.795573', '0.351074', '0.802734', '0.352051', '0.813151', '0.355469', '0.840495', '0.370117', '0.88737', '0.377441', '0.901042', '0.380859', '0.907031', '0.38208', '0.908008', '0.383887', '0.909505', '0.385254', '0.908854', '0.390625', '0.921224', '0.394043', '0.923828', '0.396484', '0.923828', '0.399902', '0.919271', '0.412109', '0.920573', '0.416016', '0.919271', '0.416992', '0.909505', '0.416016', '0.90625', '0.419922', '0.877604', '0.47168', '0.876302', '0.473633', '0.839193', '0.541992', '0.799479', '0.613281', '0.798177', '0.615234', '0.796224', '0.619141', '0.79362', '0.621094', '0.788411', '0.622559', '0.777344', '0.623047', '0.751302', '0.621094', '0.703776', '0.611816', '0.684245', '0.605957', '0.671224', '0.600586']
# x:  [0.662435, 0.658854, 0.659505, 0.660156]
# y:  [0.596289, 0.591943, 0.588379, 0.577637]
# <class 'list'>
#
# POINTS NEW:
#  [[    0.66243     0.59629]
#  [    0.65885     0.59194]
#  [    0.65951     0.58838]
#  [    0.66016     0.57764]
#  [    0.66732     0.53516]
#  [    0.66602     0.53467]
#  [    0.66797     0.53223]
#  [    0.67708      0.4751]
#  [    0.67643     0.47266]
#  [    0.67969     0.45898]
#  [    0.69141     0.38428]
#  [    0.69076     0.38281]
#  [    0.68164     0.38086]
#  [     0.6849     0.37842]
#  [     0.6875     0.37158]
#  [    0.68685     0.36914]
#  [     0.6901     0.36572]
#  [    0.69271     0.36133]
#  [    0.70703     0.36182]
#  [    0.70833     0.35791]
#  [    0.71159     0.35498]
#  [    0.71419     0.35596]
#  [    0.74219     0.35693]
#  [    0.74349     0.35596]
#  [       0.75     0.35547]
#  [     0.7526     0.35498]
#  [    0.77539     0.35107]
#  [    0.79557     0.35107]
#  [    0.80273     0.35205]
#  [    0.81315     0.35547]
#  [    0.84049     0.37012]
#  [    0.88737     0.37744]
#  [    0.90104     0.38086]
#  [    0.90703     0.38208]
#  [    0.90801     0.38389]
#  [    0.90951     0.38525]
#  [    0.90885     0.39062]
#  [    0.92122     0.39404]
#  [    0.92383     0.39648]
#  [    0.92383      0.3999]
#  [    0.91927     0.41211]
#  [    0.92057     0.41602]
#  [    0.91927     0.41699]
#  [    0.90951     0.41602]
#  [    0.90625     0.41992]
#  [     0.8776     0.47168]
#  [     0.8763     0.47363]
#  [    0.83919     0.54199]
#  [    0.79948     0.61328]
#  [    0.79818     0.61523]
#  [    0.79622     0.61914]
#  [    0.79362     0.62109]
#  [    0.78841     0.62256]
#  [    0.77734     0.62305]
#  [     0.7513     0.62109]
#  [    0.70378     0.61182]
#  [    0.68424     0.60596]
#  [    0.67122     0.60059]]
#
# image_PATH:  ../data/example_dataset_1_YOLO//train//images\vertical_2.jpg
# image_name:  vertical_2.jpg
# label_PATH:  ../data/example_dataset_1_YOLO//train//labels/vertical_2.txt
#
# ['0', '0.0400781', '0.207344', '0.0377344', '0.213037', '0.0361849', '0.216533', '0.0359896', '0.22251', '0.0367708', '0.251523', '0.0391016', '0.334629', '0.0447396', '0.544434', '0.0457161', '0.780928', '0.0505729', '0.789678', '0.058151', '0.794336', '0.0610677', '0.791426', '0.0684505', '0.795068', '0.0785677', '0.793613', '0.55349', '0.783838', '0.556406', '0.779902', '0.562227', '0.779902', '0.566706', '0.77626', '0.570013', '0.769697', '0.565729', '0.221924', '0.558932', '0.215371', '0.55931', '0.213184', '0.544935', '0.212451']
# x:  [0.0400781, 0.0377344, 0.0361849, 0.0359896]
# y:  [0.207344, 0.213037, 0.216533, 0.22251]
# <class 'list'>
#
# POINTS NEW:
#  [[   0.040078     0.20734]
#  [   0.037734     0.21304]
#  [   0.036185     0.21653]
#  [    0.03599     0.22251]
#  [   0.036771     0.25152]
#  [   0.039102     0.33463]
#  [    0.04474     0.54443]
#  [   0.045716     0.78093]
#  [   0.050573     0.78968]
#  [   0.058151     0.79434]
#  [   0.061068     0.79143]
#  [    0.06845     0.79507]
#  [   0.078568     0.79361]
#  [    0.55349     0.78384]
#  [    0.55641      0.7799]
#  [    0.56223      0.7799]
#  [    0.56671     0.77626]
#  [    0.57001      0.7697]
#  [    0.56573     0.22192]
#  [    0.55893     0.21537]
#  [    0.55931     0.21318]
#  [    0.54493     0.21245]]
# ['2', '0.696484', '0.36165', '0.697109', '0.364199', '0.701966', '0.378662', '0.715573', '0.404541', '0.792253', '0.491963', '0.873542', '0.585176', '0.875911', '0.585928', '0.888333', '0.598525', '0.894036', '0.59752', '0.89875', '0.60458', '0.901771', '0.606338', '0.907148', '0.604824', '0.912187', '0.603057', '0.916875', '0.599795', '0.918229', '0.598027', '0.911836', '0.590967', '0.912852', '0.587686', '0.901419', '0.576113', '0.901419', '0.571826', '0.736497', '0.387656', '0.715664', '0.372041']
# x:  [0.696484, 0.697109, 0.701966, 0.715573]
# y:  [0.36165, 0.364199, 0.378662, 0.404541]
# <class 'list'>
#
# POINTS NEW:
#  [[    0.69648     0.36165]
#  [    0.69711      0.3642]
#  [    0.70197     0.37866]
#  [    0.71557     0.40454]
#  [    0.79225     0.49196]
#  [    0.87354     0.58518]
#  [    0.87591     0.58593]
#  [    0.88833     0.59852]
#  [    0.89404     0.59752]
#  [    0.89875     0.60458]
#  [    0.90177     0.60634]
#  [    0.90715     0.60482]
#  [    0.91219     0.60306]
#  [    0.91687     0.59979]
#  [    0.91823     0.59803]
#  [    0.91184     0.59097]
#  [    0.91285     0.58769]
#  [    0.90142     0.57611]
#  [    0.90142     0.57183]
#  [     0.7365     0.38766]
#  [    0.71566     0.37204]]
# ['2', '0.636693', '0.496611', '0.63707', '0.507402', '0.635716', '0.509004', '0.665065', '0.82627', '0.670312', '0.829326', '0.678099', '0.830791', '0.684505', '0.829619', '0.686068', '0.823203', '0.689753', '0.826562', '0.695391', '0.825684', '0.699284', '0.822627', '0.689753', '0.737334', '0.686458', '0.736455', '0.681979', '0.736455', '0.68043', '0.731934', '0.660208', '0.507988', '0.657878', '0.505801', '0.657487', '0.495303', '0.65418', '0.493994', '0.649323', '0.493408', '0.642513', '0.493408', '0.640964', '0.493994']
# x:  [0.636693, 0.63707, 0.635716, 0.665065]
# y:  [0.496611, 0.507402, 0.509004, 0.82627]
# <class 'list'>
#
# POINTS NEW:
#  [[    0.63669     0.49661]
#  [    0.63707      0.5074]
#  [    0.63572       0.509]
#  [    0.66507     0.82627]
#  [    0.67031     0.82933]
#  [     0.6781     0.83079]
#  [    0.68451     0.82962]
#  [    0.68607      0.8232]
#  [    0.68975     0.82656]
#  [    0.69539     0.82568]
#  [    0.69928     0.82263]
#  [    0.68975     0.73733]
#  [    0.68646     0.73645]
#  [    0.68198     0.73645]
#  [    0.68043     0.73193]
#  [    0.66021     0.50799]
#  [    0.65788      0.5058]
#  [    0.65749      0.4953]
#  [    0.65418     0.49399]
#  [    0.64932     0.49341]
#  [    0.64251     0.49341]
#  [    0.64096     0.49399]]
#
# Processing in test...
# Processing in val...

# %%
list1 = [1, 2, 3, 4]
list2 = [5, 6, 7, 8]

# Zip the two lists together
zipped_list = list(zip(list1, list2))

# Convert the zipped list to a NumPy array
numpy_array = np.array(zipped_list)

print(numpy_array)
# Out:
# [[1 5]
#  [2 6]
#  [3 7]
#  [4 8]]

# %%
# Load the image
image = cv2.imread("image.jpg")

# Parse the YOLO annotation file
with open("annotation.txt", "r") as file:
    lines = file.readlines()

for line in lines:
    data = line.strip().split()
    
#     class_id, x_center, y_center, width, height = map(float, data)

#     # Convert normalized coordinates to absolute coordinates
#     img_height, img_width, _ = image.shape
#     x = int(x_center * img_width)
#     y = int(y_center * img_height)
#     w = int(width * img_width)
#     h = int(height * img_height)

#     # Draw the bounding box
#     color = (0, 255, 0)  # Green color
#     thickness = 2
#     cv2.rectangle(image, (x - w // 2, y - h // 2), (x + w // 2, y + h // 2), color, thickness)

#     # Label the bounding box
#     class_name = "Object"  # Replace with your class labels
#     cv2.putText(image, class_name, (x - w // 2, y - h // 2 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, thickness)

# # Display the image with annotations
# cv2.imshow("Annotated Image", image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
